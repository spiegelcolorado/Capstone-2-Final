# %%
import numpy as np
import pandas as pd
import seaborn as sns
import json
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('medicare-physician-and-other-supplier-national-provider-identifier-npi-aggregate-report-calendar-year-2016.csv', low_memory = False)
df2  = df.iloc[:,15:]

# %%
df2['National Provider Identifier'] = df['National Provider Identifier']
df2['Gender of the Provider'] = df['Gender of the Provider']
df2['cost_per_patient'] = df2['Total Medicare Payment Amount']/df2['Number of Medicare Beneficiaries']

# %% [markdown]
# # Wrangling Drug Information
# In the cells below I import the medicare drug dataframe. As the dataframe includes specific information for each drug, I combine all rows for each doctor into one that includes the total cost of all drugs written and total number of 30 day prescriptions written. I do this using pandas groupy and sum function. Once this is completed the dataframe is merged with the dataframe of the patient demographic information for each physician.

# %%
dr_costs = pd.read_pickle('df_dcost')
dr_costs.columns
# Out:
# Index(['npi', 'specialty_description', 'drug_name', 'generic_name',
#        'total_30_day_fill_count', 'total_drug_cost'],
#       dtype='object')

# %%
dr_costs.columns = ['National Provider Identifier', 'specialty_description', 'drug_name', 'generic_name',
       'total_30_day_fill_count', 'total_drug_cost']

# %%
dr_costs = dr_costs.drop(['drug_name', 'generic_name'], axis = 1)
dr_cost_drop = dr_costs.drop('specialty_description', axis = 1)
dr_cost_drop = dr_cost_drop.groupby('National Provider Identifier')
drug_sum = dr_cost_drop.sum()
drug_sum
# Out:
#                               total_30_day_fill_count  total_drug_cost
# National Provider Identifier
# 1003000126                                      319.0         20655.60
# 1003000142                                     1690.8        120865.38
# 1003000167                                       32.0           134.76
# 1003000282                                       30.0           328.04
# 1003000407                                     1742.2         86421.07
# ...                                               ...              ...
# 1992999825                                      220.2          7206.46
# 1992999833                                       35.0           624.65
# 1992999866                                       12.0           218.42
# 1992999874                                       31.0           325.50
# 1992999882                                      223.1          1961.22
#
# [893160 rows x 2 columns]

# %%
dr_costs = dr_costs.drop(['total_drug_cost', 'total_30_day_fill_count'], axis = 1)

# %%
print(dr_costs[:5])
dr_costs = dr_costs.drop_duplicates()
print(dr_costs.shape)
# Out:
#    National Provider Identifier specialty_description
# 0                    1003000126     Internal Medicine
# 1                    1003000126     Internal Medicine
# 2                    1003000126     Internal Medicine
# 3                    1003000126     Internal Medicine
# 4                    1003000126     Internal Medicine
# (893160, 2)

# %%
print(drug_sum.columns)
print(drug_sum.head())
drug_sum = drug_sum.merge(dr_costs, how = 'inner', on = 'National Provider Identifier')
# Out:
# Index(['total_30_day_fill_count', 'total_drug_cost'], dtype='object')
#                               total_30_day_fill_count  total_drug_cost
# National Provider Identifier
# 1003000126                                      319.0         20655.60
# 1003000142                                     1690.8        120865.38
# 1003000167                                       32.0           134.76
# 1003000282                                       30.0           328.04
# 1003000407                                     1742.2         86421.07

# %%
from collections import Counter
drug_sum_3k = drug_sum[drug_sum['total_30_day_fill_count']>=3000]
V_count = Counter(drug_sum_3k.specialty_description).most_common(10)
spec_list = []
for object in V_count:
    spec_list.append(object[0])
drug_sum= drug_sum[drug_sum.specialty_description.isin(spec_list)]

# %%
drug_sum['National Provider Identifier'] = drug_sum['National Provider Identifier'].astype(np.int64)

# %% [markdown]
# # Merge both dataframes
# Below we merge the dataframe of the cumulative drug prescription info for each doctor and the dataframe of demographic information of doctors' patient populations.  Now we are able to perform machine learning to predict physicians' total drug costs from the all of the related variables that it was merged with.

# %%
df9 = drug_sum.merge(df2, how = 'inner', on = 'National Provider Identifier')
df9.head()
# Out:
#    National Provider Identifier  total_30_day_fill_count  total_drug_cost  \
# 0                    1003000126                    319.0         20655.60
# 1                    1003000407                   1742.2         86421.07
# 2                    1003000522                  10084.4        208483.89
# 3                    1003000530                   9895.3        269677.82
# 4                    1003000753                     14.0            32.48
#
#   specialty_description  Number of HCPCS  Number of Services  \
# 0     Internal Medicine               23              1477.0
# 1       Family Practice               31              1637.0
# 2       Family Practice               55              1952.0
# 3     Internal Medicine               25              1319.0
# 4   Physician Assistant               36               116.0
#
#    Number of Medicare Beneficiaries  Total Submitted Charge Amount  \
# 0                               518                      746533.00
# 1                               401                      260033.00
# 2                               417                      368518.56
# 3                               334                      185183.00
# 4                                20                       19587.98
#
#    Total Medicare Allowed Amount  Total Medicare Payment Amount  ...  \
# 0                      159958.60                      124795.99  ...
# 1                      179134.36                      136143.38  ...
# 2                      139319.81                      106581.66  ...
# 3                      124717.40                       89429.84  ...
# 4                        5038.10                        3525.33  ...
#
#    Percent (%) of Beneficiaries Identified With Hyperlipidemia  \
# 0                                               67.0
# 1                                               69.0
# 2                                               75.0
# 3                                               62.0
# 4                                                NaN
#
#   Percent (%) of Beneficiaries Identified With Hypertension  \
# 0                                               75.0
# 1                                               75.0
# 2                                               75.0
# 3                                               67.0
# 4                                               75.0
#
#    Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 0                                               53.0
# 1                                               64.0
# 2                                               38.0
# 3                                               29.0
# 4                                                0.0
#
#    Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 0                                               12.0
# 1                                               15.0
# 2                                               11.0
# 3                                                5.0
# 4                                                0.0
#
#    Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 0                                               49.0
# 1                                               43.0
# 2                                               54.0
# 3                                               27.0
# 4                                                NaN
#
#    Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 0                                                9.0
# 1                                               12.0
# 2                                                NaN
# 3                                                3.0
# 4                                                0.0
#
#    Percent (%) of Beneficiaries Identified With Stroke  \
# 0                                               13.0
# 1                                               14.0
# 2                                                6.0
# 3                                                NaN
# 4                                                0.0
#
#    Average HCC Risk Score of Beneficiaries  Gender of the Provider  \
# 0                                   2.0239                       M
# 1                                   2.0000                       M
# 2                                   1.2619                       M
# 3                                   1.0124                       F
# 4                                   1.0672                       M
#
#   cost_per_patient
# 0       240.918900
# 1       339.509676
# 2       255.591511
# 3       267.754012
# 4       176.266500
#
# [5 rows x 61 columns]

# %% [markdown]
# # In the below cells I create a list of the ten most common medical specialties

# %%
from collections import Counter
V_count = Counter(df9.specialty_description).most_common(10)
index = 1
d = {} 
for name, count in V_count:
    d[name] = index
    index += 1
print(d)
# Out:
# {'Internal Medicine': 1, 'Family Practice': 2, 'Nurse Practitioner': 3, 'Physician Assistant': 4, 'Psychiatry': 5, 'Cardiovascular Disease (Cardiology)': 6, 'Ophthalmology': 7, 'Neurology': 8, 'Endocrinology': 9, 'General Practice': 10}

# %% [markdown]
# # Copies of merged DataFrame in entirety
# In the cell below I create copies fo the newly merged dataframe. I do this because I will be making modifications to the DataFrame to prepare it to be explored with Scikit Learn's algorithm's. However I want to be able to access the original dataframe so that I can use data exploration and plot visuals with all of the original data.

# %%
spec_df = df9.copy()
spec_unfiltered_df = df9.copy()
print(type(spec_unfiltered_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Eliminating Features and Filtering out Rows
# In the cells below I eliminate features which are missing to much information. Essentially these features have to many rows without real values and which have nan values instead. In addition I filter  out rows which have less than 44 features with real values that are not nan. There are a total of 52 features we are using. In essences rows which are missing over 17% of the used features are being removed from the dataset.
#
# The rows that we do keep but that have nan values are dealt with by the fillna function. We fill the nan values with the median values of their respective columns.

# %%
df9 = df9.drop(['Number of Black or African American Beneficiaries','Number of Asian Pacific Islander Beneficiaries','Number of Hispanic Beneficiaries','Number of American Indian/Alaska Native Beneficiaries','Number of Beneficiaries With Race Not Elsewhere Classified','Medical Suppress Indicator','Drug Suppress Indicator'], axis = 1)

df44 = df9.dropna(thresh = 44 )
df44_fill = df44.fillna(df44.median())

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import mean_squared_error as MSE
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
import functools

# %% [markdown]
# # Modifying Categorical Data
# In the cell below there is a dictionary giving numerical values to keys representing gender. Using this the gender information is remapped to bivariate numerical representations. This is important because the machine learning algorithm's only with numerical data.
#
# Similarly in the cell directly below the gender mapping, I filter the dataframe to include the ten specialties with the most doctors who prescribed over 3,000 prescription for the year. I then created Dummy Variables for each specialty. Creating Dummy Variables is essential, the reason for this is that specialties are highly predictive of drug costs, and specialties also distinct and different relationships with other feature that are predictive of drug costs

# %%
df_fill = df44_fill
genderdict = {'M':1, 'F':0}
df_fill['Gender of the Provider'] = df_fill['Gender of the Provider'].map(genderdict)
df_fill.shape
# Out:
# (270787, 54)

# %%
from collections import Counter
df_fill = df_fill[df_fill['total_30_day_fill_count']>=3000]

V_count = Counter(spec_df.specialty_description).most_common(10)
spec_list = []
for object in V_count:
    spec_list.append(object[0])

top_spec = df_fill[df_fill.specialty_description.isin(spec_list)]
dummy_df = pd.get_dummies(top_spec['specialty_description'])
df_fill = pd.concat([top_spec,dummy_df], axis = 1)

# %%
drug_avg = df_fill.loc[:,['specialty_description','total_drug_cost']]

drug_avg = drug_avg.groupby(by ='specialty_description').median()
print(drug_avg)
# Out:
#                                      total_drug_cost
# specialty_description
# Cardiovascular Disease (Cardiology)       262932.300
# Endocrinology                             868780.275
# Family Practice                           259823.530
# General Practice                          309071.070
# Internal Medicine                         334609.560
# Neurology                                 882919.930
# Nurse Practitioner                        190779.090
# Ophthalmology                             334678.410
# Physician Assistant                       180961.030
# Psychiatry                                359020.130

# %%
drug_avg = drug_avg.round()
drug_avg_dict = drug_avg.to_dict()

# %%
nested_dict = drug_avg['total_drug_cost']
nested_dict = nested_dict.to_dict()
df_fill['specialty_description_vector'] = df_fill['specialty_description'].map(nested_dict)

# %%
all_med = df_fill
all_med = all_med.drop('specialty_description', axis = 1)
all_med.shape
# Out:
# (114524, 64)

# %%
all_med = all_med.astype(np.float64)
all_med = all_med.fillna(all_med.median())
all_med = all_med[all_med['total_30_day_fill_count']>=3000]

# %% [markdown]
# # Random Sample/ GridSearchCV
# In the cells below I created a random sample made up of 20% of the rows in the entire dataframe. I created a sample to use with GridSearchCV. The reason I did this is because the data set is very large and because Grid Search is running multie fold cross variable test for each potential combination in the parameter grid, it requires alot of time. As a means to make the data more manageable we only use a random 20%.

# %%
wall_med = all_med.sample(frac=0.2, replace=False, axis = 0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X = wall_med.drop('total_drug_cost', axis = 1)
y = wall_med.total_drug_cost

# %% [markdown]
# max_features = [30, 32]
# max_depth = [25, 27]
#
# parameters = {'max_depth': max_depth, 'max_features' : max_features}
#
# rf = RandomForestRegressor(n_estimators = 150)
# clf = GridSearchCV(rf, param_grid = parameters, cv=3 )
# clf.fit(X, y)
# print(clf.best_params_)
# b_estimator = clf.best_estimator_
# print(b_estimator)

# %% [markdown]
# # Machine Learning
# Below is the machine learning code for the dataset. After splitting the dataframe into a testing set and training set, I then ran random forest with the hyperparameters I found using GridSearchCV. My end prediction is annual drug costs for each physician. I also ran Gradient Search to determine which machine learning algorithm was more effective.

# %%
X = all_med.drop('total_drug_cost', axis = 1)
#X = X_initial.drop('National Provider Identifier', axis = 1)
y = all_med.total_drug_cost
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .20, random_state = 64)

# %%
rf = RandomForestRegressor( n_estimators = 200, max_features = 30, max_depth = 25)
rf.fit(X_train, y_train)
rf_y_pred = rf.predict(X_test)
rf_SCORE = rf.score(X_test, y_test)
print(rf_SCORE)
# Out:
# 0.6501897241584265

# %%
results = rf.feature_importances_
mapped = zip(results, X.columns)
for n in mapped:
    print(n)
# Out:
# (0.00732525766479921, 'National Provider Identifier')
# (0.3488177039240431, 'total_30_day_fill_count')
# (0.005828878317630563, 'Number of HCPCS')
# (0.009595480430646253, 'Number of Services')
# (0.005022483674061374, 'Number of Medicare Beneficiaries')
# (0.0062719325323271746, 'Total Submitted Charge Amount')
# (0.01306163248452242, 'Total Medicare Allowed Amount')
# (0.0058979666877948655, 'Total Medicare Payment Amount')
# (0.010617942281173926, 'Total Medicare Standardized Payment Amount')
# (0.0037185607574140005, 'Number of HCPCS Associated With Drug Services')
# (0.0059115942359571055, 'Number of Drug Services')
# (0.004492242789358113, 'Number of Medicare Beneficiaries With Drug Services')
# (0.006545115600657971, 'Total Drug Submitted Charge Amount')
# (0.007141561257677283, 'Total Drug Medicare Allowed Amount')
# (0.006809765025763495, 'Total Drug Medicare Payment Amount')
# (0.006307018261667014, 'Total Drug Medicare Standardized Payment Amount')
# (0.006054543932959926, 'Number of HCPCS Associated With Medical Services')
# (0.006704404103025611, 'Number of Medical Services')
# (0.005685503706420031, 'Number of Medicare Beneficiaries With Medical Services')
# (0.006232789261285008, 'Total Medical Submitted Charge Amount')
# (0.005630283127017467, 'Total Medical Medicare Allowed Amount')
# (0.004973803602203698, 'Total Medical Medicare Payment Amount')
# (0.005622270328988632, 'Total Medical Medicare Standardized Payment Amount')
# (0.02001623565844488, 'Average Age of Beneficiaries')
# (0.025305868575681175, 'Number of Beneficiaries Age Less 65')
# (0.007202011219948695, 'Number of Beneficiaries Age 65 to 74')
# (0.00784809112405316, 'Number of Beneficiaries Age 75 to 84')
# (0.0063906528123445355, 'Number of Beneficiaries Age Greater 84')
# (0.022682752896854386, 'Number of Female Beneficiaries')
# (0.011631670120982795, 'Number of Male Beneficiaries\t')
# (0.007906614653099999, 'Number of Non-Hispanic White Beneficiaries\t')
# (0.016007884594663235, 'Number of Beneficiaries With Medicare Only Entitlement')
# (0.05729024874402358, 'Number of Beneficiaries With Medicare & Medicaid Entitlement')
# (0.006953775609983292, 'Percent (%) of Beneficiaries Identified With Atrial Fibrillation')
# (0.012066525774571733, 'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia')
# (0.00842574038002691, 'Percent (%) of Beneficiaries Identified With Asthma')
# (0.008275549217623352, 'Percent (%) of Beneficiaries Identified With Cancer')
# (0.009481340778488358, 'Percent (%) of Beneficiaries Identified With Heart Failure')
# (0.015222711664573164, 'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease')
# (0.007542273310565308, 'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease')
# (0.0098275216645209, 'Percent (%) of Beneficiaries Identified With Depression')
# (0.02942250470417408, 'Percent (%) of Beneficiaries Identified With Diabetes')
# (0.007593893639993248, 'Percent (%) of Beneficiaries Identified With Hyperlipidemia')
# (0.0073356368277398215, 'Percent (%) of Beneficiaries Identified With Hypertension')
# (0.01789327596079363, 'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease')
# (0.013515955523274656, 'Percent (%) of Beneficiaries Identified With Osteoporosis')
# (0.010271614736734736, 'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis')
# (0.008993537876774914, 'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders')
# (0.006513564660740011, 'Percent (%) of Beneficiaries Identified With Stroke')
# (0.01636629573019393, 'Average HCC Risk Score of Beneficiaries')
# (0.0009214624458921322, 'Gender of the Provider')
# (0.015786569100805486, 'cost_per_patient')
# (0.003410470505544341, 'Cardiovascular Disease (Cardiology)')
# (0.0059065824510720465, 'Endocrinology')
# (0.00033082746710063807, 'Family Practice')
# (0.00010975333590553884, 'General Practice')
# (0.0007559459960056765, 'Internal Medicine')
# (0.018476978198001252, 'Neurology')
# (0.0003141053050625334, 'Nurse Practitioner')
# (0.0010524308544503922, 'Ophthalmology')
# (0.0002894437395323009, 'Physician Assistant')
# (0.0005396356987654265, 'Psychiatry')
# (0.07985331245359956, 'specialty_description_vector')

# %% [markdown]
# from sklearn.ensemble import GradientBoostingRegressor
# from sklearn.model_selection import GridSearchCV
# learning_rate = [.02, .08,]
# n_estimators = [200, 300]
# max_depth = [ 25, 45]
# #max_features = [20, 30, 40, None]
#
# parameters = {'max_depth': max_depth, 'n_estimators' : n_estimators, 'max_depth' : max_depth}
#
# gbt =GradientBoostingRegressor()
# RS = GridSearchCV(gbt, param_distributions = parameters, cv=3 )
# RS.fit(X, y)
# print(RS.best_params_)
# best_estimator = RS.best_estimator_
# print(best_estimator)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor(learning_rate =.02, n_estimators = 300, max_depth = 7, max_features = 30)
gb.fit(X_train, y_train)
gb_y_pred = gb.predict(X_test)
gb_SCORE = gb.score(X_test, y_test)
print(gb_SCORE)
# Out:
# 0.6723646267251167

# %%
other_tuples = [(0.39168233029862554, 'total_30_day_fill_count'),
(0.09578280245244593, 'specialty_description_vector'),
(0.06546211174023538, 'Number of Beneficiaries With Medicare & Medicaid Entitlement'),
(0.025859865046464803, 'Number of Beneficiaries Age Less 65')]
disease_tuples = [(0.03320323920852726, 'Percent (%) of Beneficiaries Identified With Diabetes'),
(0.006521862327077195, 'Percent (%) of Beneficiaries Identified With Atrial Fibrillation'),
(0.008692775740814025, 'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia'),
(0.006730698226798446, 'Percent (%) of Beneficiaries Identified With Asthma'),
(0.006592037935781998, 'Percent (%) of Beneficiaries Identified With Cancer'),
(0.006536148321806459, 'Percent (%) of Beneficiaries Identified With Heart Failure'),
(0.0106529259710365, 'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease'),
(0.0049219776486727485, 'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease'),
(0.007631946545257106, 'Percent (%) of Beneficiaries Identified With Depression'),
(0.03320323920852726, 'Percent (%) of Beneficiaries Identified With Diabetes'),
(0.005927927910039259, 'Percent (%) of Beneficiaries Identified With Hyperlipidemia'),
(0.006385468845296912, 'Percent (%) of Beneficiaries Identified With Hypertension'),
(0.016571818142757842, 'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease'),
(0.010896825503167899, 'Percent (%) of Beneficiaries Identified With Osteoporosis'),
(0.008795396302645917, 'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis'),
(0.009531305260439044, 'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders'),
(0.005291866377859552, 'Percent (%) of Beneficiaries Identified With Stroke'),
(0.016802402609569778, 'Average HCC Risk Score of Beneficiaries'),]

# %%
disease_importance = sum([pair[0] for pair in disease_tuples])
disease_importance
# Out:
# 0.2048898620860752

# %%
results = gb.feature_importances_
mapped = zip(results, X.columns)
for n in mapped:
    print(n)
# Out:
# (0.0030618871226206802, 'National Provider Identifier')
# (0.39168233029862554, 'total_30_day_fill_count')
# (0.002956205892069453, 'Number of HCPCS')
# (0.006918442641453154, 'Number of Services')
# (0.0037012325271735132, 'Number of Medicare Beneficiaries')
# (0.0029724340591952467, 'Total Submitted Charge Amount')
# (0.01586937964944217, 'Total Medicare Allowed Amount')
# (0.0030233699814180633, 'Total Medicare Payment Amount')
# (0.008505203877554728, 'Total Medicare Standardized Payment Amount')
# (0.0033706499678446598, 'Number of HCPCS Associated With Drug Services')
# (0.00445093738298823, 'Number of Drug Services')
# (0.003521454150522924, 'Number of Medicare Beneficiaries With Drug Services')
# (0.005819728402274315, 'Total Drug Submitted Charge Amount')
# (0.007481078040194177, 'Total Drug Medicare Allowed Amount')
# (0.0060280655861940724, 'Total Drug Medicare Payment Amount')
# (0.007314055057704041, 'Total Drug Medicare Standardized Payment Amount')
# (0.004118597550866347, 'Number of HCPCS Associated With Medical Services')
# (0.0038898878500948537, 'Number of Medical Services')
# (0.0052247115361441785, 'Number of Medicare Beneficiaries With Medical Services')
# (0.005117682552025109, 'Total Medical Submitted Charge Amount')
# (0.002397203477660268, 'Total Medical Medicare Allowed Amount')
# (0.0027064063443836103, 'Total Medical Medicare Payment Amount')
# (0.002455920729966842, 'Total Medical Medicare Standardized Payment Amount')
# (0.02431548335379555, 'Average Age of Beneficiaries')
# (0.025859865046464803, 'Number of Beneficiaries Age Less 65')
# (0.0033378329990893883, 'Number of Beneficiaries Age 65 to 74')
# (0.005684163698809057, 'Number of Beneficiaries Age 75 to 84')
# (0.0032249392327965676, 'Number of Beneficiaries Age Greater 84')
# (0.022245891951091917, 'Number of Female Beneficiaries')
# (0.009440516806696133, 'Number of Male Beneficiaries\t')
# (0.005639429822080579, 'Number of Non-Hispanic White Beneficiaries\t')
# (0.015919870634711415, 'Number of Beneficiaries With Medicare Only Entitlement')
# (0.06546211174023538, 'Number of Beneficiaries With Medicare & Medicaid Entitlement')
# (0.006521862327077195, 'Percent (%) of Beneficiaries Identified With Atrial Fibrillation')
# (0.008692775740814025, 'Percent (%) of Beneficiaries Identified With Alzheimer’s Disease or Dementia')
# (0.006730698226798446, 'Percent (%) of Beneficiaries Identified With Asthma')
# (0.006592037935781998, 'Percent (%) of Beneficiaries Identified With Cancer')
# (0.006536148321806459, 'Percent (%) of Beneficiaries Identified With Heart Failure')
# (0.0106529259710365, 'Percent (%) of Beneficiaries Identified With Chronic Kidney Disease')
# (0.0049219776486727485, 'Percent (%) of Beneficiaries Identified With Chronic Obstructive Pulmonary Disease')
# (0.007631946545257106, 'Percent (%) of Beneficiaries Identified With Depression')
# (0.03320323920852726, 'Percent (%) of Beneficiaries Identified With Diabetes')
# (0.005927927910039259, 'Percent (%) of Beneficiaries Identified With Hyperlipidemia')
# (0.006385468845296912, 'Percent (%) of Beneficiaries Identified With Hypertension')
# (0.016571818142757842, 'Percent (%) of Beneficiaries Identified With Ischemic Heart Disease')
# (0.010896825503167899, 'Percent (%) of Beneficiaries Identified With Osteoporosis')
# (0.008795396302645917, 'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis')
# (0.009531305260439044, 'Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders')
# (0.005291866377859552, 'Percent (%) of Beneficiaries Identified With Stroke')
# (0.016802402609569778, 'Average HCC Risk Score of Beneficiaries')
# (0.0009820321423401443, 'Gender of the Provider')
# (0.013192153664009769, 'cost_per_patient')
# (0.003688706906560472, 'Cardiovascular Disease (Cardiology)')
# (0.005750931627281827, 'Endocrinology')
# (0.0005507385035177173, 'Family Practice')
# (8.646504306745403e-05, 'General Practice')
# (0.0009377873130577754, 'Internal Medicine')
# (0.022162243040219732, 'Neurology')
# (0.00015992169692854617, 'Nurse Practitioner')
# (0.001008133133353254, 'Ophthalmology')
# (1.2586763827907662e-05, 'Physician Assistant')
# (0.000281904871654767, 'Psychiatry')
# (0.09578280245244593, 'specialty_description_vector')

# %%
X.columns[0]
# Out:
# 'National Provider Identifier'

# %%
X.columns[0]
'total_30_day_fill_count' = .39
sum of importance of all disease = .205
specialty description vector = .095
# Out:
#   File "<ipython-input-61-e9a2405d0cf4>", line 4
#     specialty description vector = .095
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# max depth = 7, learnign rate .02, max features: 0.686

# %% [markdown]
# # Organizing/ Graphing Results
# Here I created a data frame showing the cumulative distribution of doctors by how close they were to the predicted drug costs.
# I used the Counter container type to determine the total amount of doctors above and below a specific percentage above their predicted drug costs. I then turned the data into a dataframe that I could graph

# %%
from collections import Counter
cnt = Counter()

percent_dif = (gb_y_pred - y_test)/y_test

under_100_percent_dif = (percent_dif < 1).astype('int')
print(f' Under 100 percent:{under_100_percent_dif.value_counts()}')

index = 0
dict_perc = {}
for percent in range(100):
    cnt[0] = 0
    cnt[1] = 0
    perc =  (percent_dif < index).astype('int')
    for num in perc:
        cnt[num] += 1
    value = cnt[1]/(cnt[1]+cnt[0])
    dict_perc[index] = value
    index +=.02
Prescription_plot = pd.DataFrame.from_dict(dict_perc, orient = 'index')
Prescription_plot = Prescription_plot.reset_index()
Prescription_plot.columns = ['Percentage of predicted annual prescription costs','percentage of physicians below threshold']
# Out:
#  Under 100 percent:1    21773
# 0     1132
# Name: total_drug_cost, dtype: int64

# %%
Prescription_plot
# Out:
#     Percentage of predicted annual prescription costs  \
# 0                                                0.00
# 1                                                0.02
# 2                                                0.04
# 3                                                0.06
# 4                                                0.08
# ..                                                ...
# 95                                               1.90
# 96                                               1.92
# 97                                               1.94
# 98                                               1.96
# 99                                               1.98
#
#     percentage of physicians below threshold
# 0                                   0.394062
# 1                                   0.418555
# 2                                   0.444095
# 3                                   0.469985
# 4                                   0.493342
# ..                                       ...
# 95                                  0.989566
# 96                                  0.989697
# 97                                  0.989828
# 98                                  0.990090
# 99                                  0.990264
#
# [100 rows x 2 columns]

# %%
prescription_table = Prescription_plot.iloc[[10,20,30,40,50,60,70,80,99]]
prescription_table.columns = ['Percentage above predicted annual prescription costs', 'percentage of physicians below threshold']
prescription_table.to_excel("prescription_tabless.xlsx")

# %%
import seaborn as sns
plt.rcParams.update({'font.size': 40})


sns.lmplot(x = 'Percentage of predicted annual prescription costs', y ='percentage of physicians below threshold', data = Prescription_plot, fit_reg = False,  aspect=1, height=8)
plt.xticks( ticks = [0.00,0.25,0.50,0.75,1.00, 1.25,1.50,1.75,2.00], labels= ['100%', '125%', '150%', '175%', '200%', '225%', '250%', '275%','300%'] )
plt.title('Doctors by percent difference from prediction')
plt.savefig('doctors by percent difference from prediction.png')

# %% [markdown]
# # Graphic Plots
# Below I write code to get a dataframe including the 15 most common specialties. Then create plots showing the relationship's between average prescription cost for specific specialties and the specialists' percentage of patients with specific chronic illness. I also create a plot that simply shows the distribution and range of the average prescriptions costs across the most common specialties.

# %%
from collections import Counter
spec_df = spec_df[spec_df['total_30_day_fill_count']>=3000]

HCC_df = spec_df.copy()
spec_df = spec_df[spec_df['specialty_description']!= 'Nurse Practitioner']
spec_df = spec_df[spec_df['specialty_description']!= 'Physician Assistant']
spec_df = spec_df[spec_df['specialty_description']!= 'Orthopedic Surgery']
V_count = Counter(spec_df.specialty_description).most_common(20)
print(V_count)
spec_list = V_count[0]
spec_list = []
for object in V_count:
    spec_list.append(object[0])
print(spec_list)

top_spec = spec_df[spec_df.specialty_description.isin(spec_list)]
top_spec['cost_per_prescription'] = top_spec['total_drug_cost']/ top_spec['total_30_day_fill_count']
HCC_df['cost_per_prescription'] = top_spec['total_drug_cost']/ top_spec['total_30_day_fill_count']
spec_unfiltered_df['cost_per_prescription'] = spec_unfiltered_df['total_drug_cost']/ spec_unfiltered_df['total_30_day_fill_count']

top_spec.head()
print(spec_list)
top_spec
# Out:
# [('Family Practice', 47570), ('Internal Medicine', 43847), ('Cardiovascular Disease (Cardiology)', 12206), ('Psychiatry', 4911), ('Ophthalmology', 3598), ('Neurology', 3166), ('Endocrinology', 2835), ('General Practice', 2644)]
# ['Family Practice', 'Internal Medicine', 'Cardiovascular Disease (Cardiology)', 'Psychiatry', 'Ophthalmology', 'Neurology', 'Endocrinology', 'General Practice']
# ['Family Practice', 'Internal Medicine', 'Cardiovascular Disease (Cardiology)', 'Psychiatry', 'Ophthalmology', 'Neurology', 'Endocrinology', 'General Practice']
#         National Provider Identifier  total_30_day_fill_count  \
# 2                         1003000522                  10084.4
# 3                         1003000530                   9895.3
# 5                         1003000902                   9005.6
# 6                         1003000936                   3061.0
# 8                         1003001884                   4713.7
# ...                              ...                      ...
# 375049                    1992996375                   3454.4
# 375056                    1992997647                   6233.1
# 375058                    1992998645                   8805.7
# 375060                    1992999122                  24736.9
# 375062                    1992999551                   4804.9
#
#         total_drug_cost specialty_description  Number of HCPCS  \
# 2             208483.89       Family Practice               55
# 3             269677.82     Internal Medicine               25
# 5             204088.52       Family Practice               35
# 6             137785.22     Internal Medicine               68
# 8              55843.47       Family Practice               42
# ...                 ...                   ...              ...
# 375049        878740.46     Internal Medicine               48
# 375056        192166.48       Family Practice                6
# 375058        241994.80     Internal Medicine               32
# 375060        732161.58     Internal Medicine               51
# 375062         78509.11     Internal Medicine               40
#
#         Number of Services  Number of Medicare Beneficiaries  \
# 2                   1952.0                               417
# 3                   1319.0                               334
# 5                    916.0                               258
# 6                   4670.0                              1374
# 8                    640.0                               145
# ...                    ...                               ...
# 375049              3987.0                               417
# 375056                73.0                                22
# 375058              4164.0                               562
# 375060              7991.0                              1398
# 375062               832.0                               240
#
#         Total Submitted Charge Amount  Total Medicare Allowed Amount  \
# 2                           368518.56                      139319.81
# 3                           185183.00                      124717.40
# 5                           106047.00                       59687.40
# 6                           565333.00                      278921.17
# 8                            63048.00                       42913.01
# ...                               ...                            ...
# 375049                      250353.00                      118527.76
# 375056                       10971.00                        6681.43
# 375058                     1111256.00                      363839.24
# 375060                      821639.00                      602725.38
# 375062                      112168.84                       61756.46
#
#         Total Medicare Payment Amount  ...  \
# 2                           106581.66  ...
# 3                            89429.84  ...
# 5                            40810.00  ...
# 6                           208615.23  ...
# 8                            34374.93  ...
# ...                               ...  ...
# 375049                       88108.13  ...
# 375056                        5133.62  ...
# 375058                      282301.54  ...
# 375060                      461352.08  ...
# 375062                       43485.98  ...
#
#         Percent (%) of Beneficiaries Identified With Hypertension  \
# 2                                                    75.0
# 3                                                    67.0
# 5                                                    70.0
# 6                                                    75.0
# 8                                                    71.0
# ...                                                   ...
# 375049                                               75.0
# 375056                                               75.0
# 375058                                               75.0
# 375060                                               72.0
# 375062                                               60.0
#
#        Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 2                                                    38.0
# 3                                                    29.0
# 5                                                    25.0
# 6                                                    65.0
# 8                                                    35.0
# ...                                                   ...
# 375049                                               44.0
# 375056                                                NaN
# 375058                                               50.0
# 375060                                               49.0
# 375062                                               21.0
#
#         Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 2                                                    11.0
# 3                                                     5.0
# 5                                                     7.0
# 6                                                     6.0
# 8                                                     8.0
# ...                                                   ...
# 375049                                               13.0
# 375056                                                NaN
# 375058                                               11.0
# 375060                                               11.0
# 375062                                               13.0
#
#         Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 2                                                    54.0
# 3                                                    27.0
# 5                                                    41.0
# 6                                                    48.0
# 8                                                    44.0
# ...                                                   ...
# 375049                                               45.0
# 375056                                                NaN
# 375058                                               44.0
# 375060                                               47.0
# 375062                                               38.0
#
#         Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 2                                                     NaN
# 3                                                     3.0
# 5                                                     5.0
# 6                                                     4.0
# 8                                                     NaN
# ...                                                   ...
# 375049                                                3.0
# 375056                                                NaN
# 375058                                                4.0
# 375060                                                1.0
# 375062                                                NaN
#
#         Percent (%) of Beneficiaries Identified With Stroke  \
# 2                                                     6.0
# 3                                                     NaN
# 5                                                     NaN
# 6                                                    12.0
# 8                                                     NaN
# ...                                                   ...
# 375049                                                5.0
# 375056                                                0.0
# 375058                                               14.0
# 375060                                                6.0
# 375062                                                5.0
#
#         Average HCC Risk Score of Beneficiaries  Gender of the Provider  \
# 2                                        1.2619                       M
# 3                                        1.0124                       F
# 5                                        1.2416                       F
# 6                                        1.8353                       M
# 8                                        1.1660                       F
# ...                                         ...                     ...
# 375049                                   1.9668                       F
# 375056                                   2.0573                       M
# 375058                                   2.2050                       F
# 375060                                   1.3262                       M
# 375062                                   1.0951                       F
#
#         cost_per_patient cost_per_prescription
# 2             255.591511             20.673901
# 3             267.754012             27.253122
# 5             158.178295             22.662401
# 6             151.830590             45.013139
# 8             237.068483             11.847056
# ...                  ...                   ...
# 375049        211.290480            254.382949
# 375056        233.346364             30.830001
# 375058        502.315907             27.481609
# 375060        330.008641             29.597952
# 375062        181.191583             16.339385
#
# [120777 rows x 62 columns]

# %%
HCC_df
# Out:
#         National Provider Identifier  total_30_day_fill_count  \
# 2                         1003000522                  10084.4
# 3                         1003000530                   9895.3
# 5                         1003000902                   9005.6
# 6                         1003000936                   3061.0
# 8                         1003001884                   4713.7
# ...                              ...                      ...
# 375049                    1992996375                   3454.4
# 375056                    1992997647                   6233.1
# 375058                    1992998645                   8805.7
# 375060                    1992999122                  24736.9
# 375062                    1992999551                   4804.9
#
#         total_drug_cost specialty_description  Number of HCPCS  \
# 2             208483.89       Family Practice               55
# 3             269677.82     Internal Medicine               25
# 5             204088.52       Family Practice               35
# 6             137785.22     Internal Medicine               68
# 8              55843.47       Family Practice               42
# ...                 ...                   ...              ...
# 375049        878740.46     Internal Medicine               48
# 375056        192166.48       Family Practice                6
# 375058        241994.80     Internal Medicine               32
# 375060        732161.58     Internal Medicine               51
# 375062         78509.11     Internal Medicine               40
#
#         Number of Services  Number of Medicare Beneficiaries  \
# 2                   1952.0                               417
# 3                   1319.0                               334
# 5                    916.0                               258
# 6                   4670.0                              1374
# 8                    640.0                               145
# ...                    ...                               ...
# 375049              3987.0                               417
# 375056                73.0                                22
# 375058              4164.0                               562
# 375060              7991.0                              1398
# 375062               832.0                               240
#
#         Total Submitted Charge Amount  Total Medicare Allowed Amount  \
# 2                           368518.56                      139319.81
# 3                           185183.00                      124717.40
# 5                           106047.00                       59687.40
# 6                           565333.00                      278921.17
# 8                            63048.00                       42913.01
# ...                               ...                            ...
# 375049                      250353.00                      118527.76
# 375056                       10971.00                        6681.43
# 375058                     1111256.00                      363839.24
# 375060                      821639.00                      602725.38
# 375062                      112168.84                       61756.46
#
#         Total Medicare Payment Amount  ...  \
# 2                           106581.66  ...
# 3                            89429.84  ...
# 5                            40810.00  ...
# 6                           208615.23  ...
# 8                            34374.93  ...
# ...                               ...  ...
# 375049                       88108.13  ...
# 375056                        5133.62  ...
# 375058                      282301.54  ...
# 375060                      461352.08  ...
# 375062                       43485.98  ...
#
#         Percent (%) of Beneficiaries Identified With Hypertension  \
# 2                                                    75.0
# 3                                                    67.0
# 5                                                    70.0
# 6                                                    75.0
# 8                                                    71.0
# ...                                                   ...
# 375049                                               75.0
# 375056                                               75.0
# 375058                                               75.0
# 375060                                               72.0
# 375062                                               60.0
#
#        Percent (%) of Beneficiaries Identified With Ischemic Heart Disease  \
# 2                                                    38.0
# 3                                                    29.0
# 5                                                    25.0
# 6                                                    65.0
# 8                                                    35.0
# ...                                                   ...
# 375049                                               44.0
# 375056                                                NaN
# 375058                                               50.0
# 375060                                               49.0
# 375062                                               21.0
#
#         Percent (%) of Beneficiaries Identified With Osteoporosis  \
# 2                                                    11.0
# 3                                                     5.0
# 5                                                     7.0
# 6                                                     6.0
# 8                                                     8.0
# ...                                                   ...
# 375049                                               13.0
# 375056                                                NaN
# 375058                                               11.0
# 375060                                               11.0
# 375062                                               13.0
#
#         Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis  \
# 2                                                    54.0
# 3                                                    27.0
# 5                                                    41.0
# 6                                                    48.0
# 8                                                    44.0
# ...                                                   ...
# 375049                                               45.0
# 375056                                                NaN
# 375058                                               44.0
# 375060                                               47.0
# 375062                                               38.0
#
#         Percent (%) of Beneficiaries Identified With Schizophrenia / Other Psychotic Disorders  \
# 2                                                     NaN
# 3                                                     3.0
# 5                                                     5.0
# 6                                                     4.0
# 8                                                     NaN
# ...                                                   ...
# 375049                                                3.0
# 375056                                                NaN
# 375058                                                4.0
# 375060                                                1.0
# 375062                                                NaN
#
#         Percent (%) of Beneficiaries Identified With Stroke  \
# 2                                                     6.0
# 3                                                     NaN
# 5                                                     NaN
# 6                                                    12.0
# 8                                                     NaN
# ...                                                   ...
# 375049                                                5.0
# 375056                                                0.0
# 375058                                               14.0
# 375060                                                6.0
# 375062                                                5.0
#
#         Average HCC Risk Score of Beneficiaries  Gender of the Provider  \
# 2                                        1.2619                       M
# 3                                        1.0124                       F
# 5                                        1.2416                       F
# 6                                        1.8353                       M
# 8                                        1.1660                       F
# ...                                         ...                     ...
# 375049                                   1.9668                       F
# 375056                                   2.0573                       M
# 375058                                   2.2050                       F
# 375060                                   1.3262                       M
# 375062                                   1.0951                       F
#
#         cost_per_patient cost_per_prescription
# 2             255.591511             20.673901
# 3             267.754012             27.253122
# 5             158.178295             22.662401
# 6             151.830590             45.013139
# 8             237.068483             11.847056
# ...                  ...                   ...
# 375049        211.290480            254.382949
# 375056        233.346364             30.830001
# 375058        502.315907             27.481609
# 375060        330.008641             29.597952
# 375062        181.191583             16.339385
#
# [120777 rows x 62 columns]

# %%
HCC_PCP_df = HCC_df[HCC_df['specialty_description'] == 'Internal Medicine']

sns.set(rc={'figure.figsize':(10,6)})
sns.regplot(x = 'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis', y = 'cost_per_prescription', data = HCC_PCP_df )
plt.title("Correlation between percentage of patients diagnosed with Rheumatoid Arthritis and internal medicine annual prescription costs")
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)
plt.ylim(0, 300)
# Out:
# (0, 300)

# %%
HCC_cardio_df = HCC_df[HCC_df['specialty_description'] == 'Cardiovascular Disease (Cardiology)']

sns.set(rc={'figure.figsize':(10,6)})
sns.regplot(x = 'Percent (%) of Beneficiaries Identified With Rheumatoid Arthritis / Osteoarthritis', y = 'cost_per_prescription', data = HCC_cardio_df )
plt.title("Percentage of cardiologist's patients diagnosed with Rheumatoid Arthritis vs cost per prescription")
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}
plt.ylim(0, 300)
plt.savefig('Cardiology_Arthritis.png')

# %%
plt.rcParams.update({'font.size': 100})

HCC_fp_df = HCC_df[HCC_df['specialty_description'] == 'Family Practice']

sns.set(rc={'figure.figsize':(15,8)})
sns.regplot(x = 'Average HCC Risk Score of Beneficiaries', y = 'cost_per_prescription', data = HCC_fp_df )
plt.ylim(0, 200)
plt.ylim(0, 200)


#sns.set(font_scale=5)
plt.title("Relationship between patients' average HHC Risk Score and cost per prescription for Family Practice Doctors")
plt.savefig('fp_HCC_SCORE.png')
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.regplot(x = 'Average HCC Risk Score of Beneficiaries', y = 'cost_per_prescription', data = spec_unfiltered_df )
plt.ylim(0, 400)
plt.ylim(0, 200)
#sns.set(font_scale=5)
plt.title("Relationship between patients' average HHC Risk Score and cost per prescription for all doctors")
plt.savefig('All_docs_HCC_SCORE.png')
plt.show()

# %%
Int_unfiltered_df = spec_unfiltered_df[spec_unfiltered_df['specialty_description'] == 'Internal Medicine']
sns.regplot(Int_unfiltered_df['total_30_day_fill_count'],Int_unfiltered_df['cost_per_prescription'], scatter = True, fit_reg= True)
plt.title('Average Prescription drug cost by number of prescriptions written')
# Out:
# Text(0.5, 1.0, 'Average Prescription drug cost by number of prescriptions written')

# %%
sns.regplot(spec_unfiltered_df['total_30_day_fill_count'],spec_unfiltered_df['cost_per_prescription'], scatter = True, fit_reg= True)
plt.title('Total number of prescriptions filled vs cost per prescription')
plt.savefig('number_of_prescriptions_vs_avg_cost')
plt.show()
